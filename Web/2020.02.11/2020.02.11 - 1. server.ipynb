# %% [markdown]
# - 아래 셀 실행시키면 listening이 나옴
# - client.ipynb를 실행시키면 아래의 결과를 받아옴
# - GET방식

# %%
import socket

server_socket = socket.socket(socket.AF_INET,   # 통신 채널 선택
                              socket.SOCK_STREAM) # TCP 방식으로 하는거

server_socket.bind(('localhost', 12345))  # bind :  12345포트의 아이피에서  서버로서 동작시키겠다. 
server_socket.listen(0)  # listen : 몇 개까지 동시에 참여시킬 것인지  / 0은 자기가 알아서 한다는 뜻  (서버모드로 동작하겠다.)
print("listening")

client_socket, addr = server_socket.accept() # 클라이언트가 접속이 되기 전까지는 대기상태로 머물고
print("accepting")
data = client_socket.recv(65535) # data : 접속이 되면 64k단위로 쪼개서 보냄

print("recieve : " + data.decode()) # 받은 코드를 디코딩 해서 출력

client_socket.send(data)
print("send data")

client_socket.close()
print("종료")
# Out:
# listening
# accepting
# hello
# send data
# 종료

# %% [markdown]
# ---

# %% [markdown]
# - 위에 있는 코드에서 불필요한 것들 다 빼고 다시 쓴 것
# - 밑의 셀을 실행시킨 후, 크롬의 URL창에 http://localhost:80을 입력하면 결과가 아래에 뜸
# - POST방식으로 받으려면 form.html(같은 폴더에 있음)을 만들어 놓고 아래의 셀을 실행시킨 다음 form.html에서 아무 글자나 넣고 submit 하면 결과가 뜸

# %%
# simple http server
import socket

server_socket = socket.socket(socket.AF_INET,   # 통신 채널 선택
                              socket.SOCK_STREAM) # TCP 방식으로 하는거

server_socket.bind(('localhost', 80))  # bind :  12345포트의 아이피에서  서버로서 동작시키겠다. 
server_socket.listen(0)  # listen : 몇 개까지 동시에 참여시킬 것인지  / 0은 자기가 알아서 한다는 뜻  (서버모드로 동작하겠다.)
print("listening")

client_socket, addr = server_socket.accept() # 클라이언트가 접속이 되기 전까지는 대기상태로 머물고
print("accepting")
data = client_socket.recv(65535) # data : 접속이 되면 64k단위로 쪼개서 보냄

print("recieve : " + data.decode()) # 받은 코드를 디코딩 해서 출력

# client_socket.send(data)
# print("send data")

client_socket.close()
print("종료")
# Out:
# listening
# accepting
# recieve : POST / HTTP/1.1
# Host: 127.0.0.1
# Connection: keep-alive
# Content-Length: 7
# Cache-Control: max-age=0
# Upgrade-Insecure-Requests: 1
# Origin: null
# Content-Type: application/x-www-form-urlencoded
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.87 Safari/537.36
# Sec-Fetch-Dest: document
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9
# Sec-Fetch-Site: cross-site
# Sec-Fetch-Mode: navigate
# Sec-Fetch-User: ?1
# Accept-Encoding: gzip, deflate, br
# Accept-Language: ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7
#
# id=asdf
# 종료

# %%
# simple http server
import socket

server_socket = socket.socket(socket.AF_INET,   # 통신 채널 선택
                              socket.SOCK_STREAM) # TCP 방식으로 하는거

server_socket.bind(('localhost', 80))  # bind :  12345포트의 아이피에서  서버로서 동작시키겠다. 
server_socket.listen(0)  # listen : 몇 개까지 동시에 참여시킬 것인지  / 0은 자기가 알아서 한다는 뜻  (서버모드로 동작하겠다.)
print("listening")

client_socket, addr = server_socket.accept() # 클라이언트가 접속이 되기 전까지는 대기상태로 머물고
print("accepting")
data = client_socket.recv(65535) # data : 접속이 되면 64k단위로 쪼개서 보냄

print("recieve : " + data.decode()) # 받은 코드를 디코딩 해서 출력

client_socket.send('HTTP/1.0 200 OK\r\n\r\n<font color=red>Hello</font>'.encode("utf-8"))

client_socket.close()
print("종료")
# Out:
# listening

# %% [markdown]
# ### 밑의 셀은 무한루프임

# %%
import socket
from datetime import datetime

server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

server_socket.bind(('localhost', 80))
server_socket.listen(0)
print("listening")

while True :
    client_socket, addr = server_socket.accept()
    print("accepting")
    data = client_socket.recv(65535)
    print("receive : " + data.decode())
    
    header = 'HTTP/1.0 200 OK\r\n\r\n'
    html = 'hello' + str(datetime.now())
    client_socket.send(header.encode("utf-8"))
    client_socket.send(html.encode("utf-8"))
    client_socket.close()

# %%
import socket
from datetime import datetime

server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

server_socket.bind(('localhost', 80))
server_socket.listen(0)
print("listening")

if True :
    client_socket, addr = server_socket.accept()
    print("accepting")
    data = client_socket.recv(65535)
    data = data.decode()
    
    headers = data.split("\r\n")
    print(headers[0])
    print(headers[0].split(" ")[1])
    
#     html = 'hello' + str(datetime.now())
    client_socket.send(headers.encode("utf-8"))
    client_socket.send(html.encode("utf-8"))
    client_socket.close()
# Out:
# listening
# accepting
# GET / HTTP/1.1
# /
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-1dfecc29049b> in <module>
#      19
#      20 #     html = 'hello' + str(datetime.now())
# ---> 21     client_socket.send(headers.encode("utf-8"))
#      22     client_socket.send(html.encode("utf-8"))
#      23     client_socket.close()
#
# AttributeError: 'list' object has no attribute 'encode'

# %%
filename = "/index.html"

file = open("." + filename, 'rt', encoding='utf-8')

print(file.read())
# Out:
# <font color=red> My Web Server </fornt>

# %%
import socket
from datetime import datetime

server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

server_socket.bind(('localhost', 80))
server_socket.listen(0)
print("listening")

if True :
    client_socket, addr = server_socket.accept()
    print("accepting")
    data = client_socket.recv(65535)
    data = data.decode()
    
    headers = data.split("\r\n")
    filename = headers[0].split(" ")[1]
    file = open("." + filename, 'rt', encoding='utf-8')
    html = file.read()
    
    header = 'HTTP/1.0 200 OK\r\n\r\n'
    
    client_socket.send(header.encode("utf-8"))
    client_socket.send(html.encode("utf-8"))
    client_socket.close()

# %% [markdown]
# ---

# %%
# 미리 같은 디렉토리 경로 안에 test.py 파일을 만들어 놔야 함

import subprocess

# 도스를 활용하여 python 프로세스를 실행하는 것
output = subprocess.check_output(['python.exe', 'test.py'])

print(type(output))  # output은 byte 데이터
print('\n')

print(output) 
print('\n')

# print(type(output.decode()))   # decode는 byte를 string으로 바꿔줌(but 한글은 안됌)
print('\n')

# print(output.decode())
print(output.decode('cp949'))  #한글을 제대로 처리하려면 cp949가 필요함
# Out:
# <class 'bytes'>
#
#
# b' \r\n<html>\r\n    <head>\r\n        <meta charset="utf-8">\r\n    </head>\r\n    \r\n    <body>\r\n        <font color=red> \xc7\xd1\xb1\xdb </font>\r\n    </body>\r\n</html>\r\n\r\n'
#
#
#
#
#
# <html>
#     <head>
#         <meta charset="utf-8">
#     </head>
#
#     <body>
#         <font color=red> 한글 </font>
#     </body>
# </html>

# %%
import socket
from datetime import datetime
import subprocess

server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

server_socket.bind(('localhost', 80))
server_socket.listen(0)
print("listening")

while True :
    client_socket, addr = server_socket.accept()
    print("accepting")
    data = client_socket.recv(65535)
    data = data.decode()
    print(data)
    
    try:
        headers = data.split("\r\n")
        filename = headers[0].split(" ")[1]

        if '.py' in filename:
            header = 'HTTP/1.0 200 OK\r\n\r\n'
            html = subprocess.check_output(['python.exe', '.' + filename])
            html = html.decode('cp949')
            client_socket.send(header.encode("utf-8"))
            client_socket.send(html.encode("utf-8"))
            output = subprocess.check_output(['python.exe', 'test.py'])
            

        elif '.html' in filename or '.txt' in filename :
            file = open("." + filename, 'rt', encoding='utf-8')
            html = file.read()
            header = 'HTTP/1.0 200 OK\r\n\r\n'
            client_socket.send(header.encode("utf-8"))
            client_socket.send(html.encode("utf-8"))
            file.close()

        elif '.jpg' in filename:
            client_socket.send('HTTP/1.1 200 OK\r\n'.encode())
            client_socket.send("Content-Type: image/jpg\r\n".encode())
            client_socket.send("Accept-Ragnes: bytes\r\n\r\n".encode())
            file = open("." + filename, 'rb')
            client_socket.send(file.read())
            file.close()

        elif '.jpg' in filename:
            client_socket.send('HTTP/1.1 200 OK\r\n'.encode())
            client_socket.send("Content-Type: image/jpg\r\n".encode())
            client_socket.send("Accept-Ragnes: bytes\r\n\r\n".encode())
            file = open("." + filename, 'rb')
            client_socket.send(file.read())
            file.close()

        else:
            header = 'HTTP/1.0 404 File Not Found\r\n\r\n'
            client_socket.send(header.encode("utf-8"))
    except Exception as e:
        print(e)
    client_socket.close()
# Out:
# listening
# accepting
#
# list index out of range
# accepting
# GET /test.py HTTP/1.1
# Host: localhost
# Connection: keep-alive
# Cache-Control: max-age=0
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.87 Safari/537.36
# Sec-Fetch-Dest: document
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9
# Sec-Fetch-Site: none
# Sec-Fetch-Mode: navigate
# Sec-Fetch-User: ?1
# Accept-Encoding: gzip, deflate, br
# Accept-Language: ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7
# ...

# %%
import socket
import threading
from datetime import datetime
import subprocess

def httpprocess(client_socket) :
    data = client_socket.recv(65535)   
    data = data.decode()
    print(data)
    try :    
        headers = data.split("\r\n")
        filename = headers[0].split(" ")[1]
        
        if '.py' in filename:
            header = 'HTTP/1.0 200 OK\r\n'   
            html = subprocess.check_output(['python.exe', '.' + filename])
            html = html.decode('cp949')
            client_socket.send(header.encode("utf-8"))
            client_socket.send("Content-Type: text/html\r\n\r\n".encode())
            client_socket.send(html.encode("utf-8"))            
        elif '.html' in filename:
            file = open("."+ filename, 'rt', encoding='utf-8')
            html = file.read()    
            header = 'HTTP/1.0 200 OK\r\n\r\n'        
            client_socket.send(header.encode("utf-8"))
            client_socket.send(html.encode("utf-8"))
        elif '.jpg' in filename or '.ico' in filename:         
            client_socket.send('HTTP/1.1 200 OK\r\n'.encode())
            client_socket.send("Content-Type: image/jpg\r\n".encode())
            client_socket.send("Accept-Ranges: bytes\r\n\r\n".encode())
            file = open("." + filename, "rb")            
            client_socket.send(file.read())  
            file.close()               
        else :
            header = 'HTTP/1.0 404 File Not Found\r\n\r\n'        
            client_socket.send(header.encode("utf-8"))
    except Exception as e :
        print(e)         
    client_socket.close()


server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
server_socket.bind(('localhost', 80))
server_socket.listen(0)
print("listening")

while  True :
    client_socket, addr = server_socket.accept()
    
    # 3초이상 걸리는 socket은 걸러냄(즉 error 처리함)
    # 가끔 내용없이 들어오는 요청이 있어서 이런거 걸러내는 용도
    client_socket.settimeout(3)
    print("accepting")
    
    # 밑에는 사실 httpprocess(client_socket)과 같은 표현인데 차이점은 동시에 여러 동기를 돌리기 위해서 
    t = threading.Thread(target=httpprocess, args=(client_socket,)) # 
    t.start()
# Out:
# listening
# accepting
# GET /test3.py HTTP/1.1
# Host: 127.0.0.1
# Connection: keep-alive
# Cache-Control: max-age=0
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.87 Safari/537.36
# Sec-Fetch-Dest: document
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9
# Sec-Fetch-Site: none
# Sec-Fetch-Mode: navigate
# Sec-Fetch-User: ?1
# Accept-Encoding: gzip, deflate, br
# Accept-Language: ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7
#
#
# accepting
# GET /1.png HTTP/1.1
# Host: 127.0.0.1
# Connection: keep-alive
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.87 Safari/537.36
# Sec-Fetch-Dest: image
# Accept: image/webp,image/apng,image/*,*/*;q=0.8
# Sec-Fetch-Site: same-origin
# Sec-Fetch-Mode: no-cors
# Referer: http://127.0.0.1/test3.py
# ...

# %%
# def render(html, data) :
#     for i in range(1,4):
#         html = html.replace(f"v{i}", data[f"v{i}"])
#     return  html

# 위에꺼랑 같음
def render(html, data) :
    for v in data :
        html = html.replace("@"+v, data[v])
    return html


    
html = "hello @v1   test @v2   item @v3 "
data = {"v1":"안녕하세요",  "v2":"이순신", "v3":"^^"}
html = render(html, data)
print(html)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f5da59f02f5c> in <module>
#      18
#      19 data = {"v1":"안녕하세요",  "v2":"이순신", "v3":"^^"}
# ---> 20 HTML(renderfile("templet.html", data))
#      21
#
# NameError: name 'HTML' is not defined

# %%
from IPython.core.display import HTML

def render(html, data) :
    for v in data :
        html = html.replace("@"+v, data[v])
    return html

def renderfile(file, data) :
    html = open(file, "rt", encoding="utf-8").read()
    for v in data :
        html = html.replace("@"+v, data[v])
    return html

data = {"title":"나의 홈페이지",  "name":"이순신", "email":"^^"}
HTML(renderfile("test2.py", data))
# Out:
# html = """
# <html>
#    <head>
#       <meta charset="utf-8">
#    </head>
#
#    <body>
#       <font color=cyan> @out</font>
#
#       <table border=1>
#          <tr>
#             <td> 이름 </td> <td> <font color=Plum> 이순신 </font> </td>
#          </tr>
#          <tr>
#             <td> email </td> <td> ^^ </td>
#          </tr>
#       </table>
#    </body>
# </html>
# """
#
# html = html.replace("@out",  "제목출력")
# html = html.replace("이순신",  "정남호")
# html = html.replace("^^",  "jnh7807@gmail.com")
#
# print(html)
