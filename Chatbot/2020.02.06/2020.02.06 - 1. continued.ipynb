# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# ![3.PNG](attachment:3.PNG)

# %% [markdown]
# URL 창에다가 127.0.0.1:88/index.html 실행하면 이렇게 나온다
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# ---

# %% [markdown]
# ### 이번엔 여러 파일들을 넣어놓자
# ![5.PNG](attachment:5.PNG)

# %% [markdown]
# - 웹브라우저의 URL창에서 127.0.0.1:80/11890045.ppt을 입력하면 해당 ppt가 다운로드가 됌!
# - 뿐만 아니라 zip파일, exe파일 같은 것도 넣으면 다운로드가 됌!
# - 이미지 파일은 웹에서 직접 실행이 됌
# - mp3파일도 직접 실행이 됌

# %% [markdown]
# ---

# %% [markdown]
# - 밑처럼 저장하고 웹브라우저의 URL에 127.0.0.1:80/index.html 실행하면
# - 결과가 밑의 그림처럼 나옴
# ![8.PNG](attachment:8.PNG)
# ![9.PNG](attachment:9.PNG)

# %% [markdown]
# dialogflow에서 integrations의 webdemo에서 아래 부분을 복사해서
# ![10.PNG](attachment:10.PNG)

# %% [markdown]
# homepage 폴더의 index.html파일에 붙여넣고 저장하면
# ![11.PNG](attachment:11.PNG)

# %% [markdown]
# 결과가 이렇게 나옴!
# ![12.PNG](attachment:12.PNG)

# %% [markdown]
# ---

# %% [markdown]
# ## Summary :
# 1. http는 download서버다(완료 후 실행할 뿐, 연결x)
# 2. 대다수의 기능은 브라우저의 기능
